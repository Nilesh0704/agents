# %%
from dotenv import load_dotenv

# %%
load_dotenv(override=True)
# Out:
# True

# %%
import os
openai_api_key = os.getenv("OPENAI_API_KEY")

if openai_api_key:
    print("API key loaded successfully!")
else:
    print("API key not found in environment variables.")

# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.
# Out:
# API key loaded successfully!

# %%
from openai import OpenAI

# %%
openai_python_client = OpenAI()

# %%
messages = [{"role": "user", "content": "what is 2+2"}]

# %%
response = openai_python_client.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages,
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 equals 4.

# %%
question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
reponse = openai_python_client.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages,
)

question = reponse.choices[0].message.content

print(question)
# Out:
# A train leaves a station traveling east at 60 miles per hour. Another train leaves the same station traveling west at 90 miles per hour. At what point, in terms of time, will the distance between the two trains be equal to 300 miles?

# %%
messages = [{"role": "user", "content": question}]

# %%
response = openai_python_client.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages,
)

answer = response.choices[0].message.content

print(answer)
# Out:
# Let's denote the time in hours since the trains departed as \( t \).
#
# The first train, traveling east at 60 miles per hour, will have traveled a distance of:
# \[
# \text{Distance of the first train} = 60t
# \]
#
# The second train, traveling west at 90 miles per hour, will have traveled a distance of:
# \[
# \text{Distance of the second train} = 90t
# \]
#
# Since the two trains are traveling in opposite directions, the total distance between them will be the sum of the distances traveled by both trains:
# \[
# \text{Total distance} = 60t + 90t = 150t
# \]
#
# We want to find the time \( t \) at which the distance between the two trains is equal to 300 miles:
# \[
# 150t = 300
# \]
#
# Now, solving for \( t \):
# \[
# t = \frac{300}{150} = 2
# \]
#
# Thus, the time at which the distance between the two trains will be 300 miles is \( \boxed{2} \) hours.

# %%
from IPython.display import Markdown, display

display(Markdown(f"# {answer}"))
# Out:
# # Let's denote the time in hours since the trains departed as \( t \).
#
# The first train, traveling east at 60 miles per hour, will have traveled a distance of:
# \[
# \text{Distance of the first train} = 60t
# \]
#
# The second train, traveling west at 90 miles per hour, will have traveled a distance of:
# \[
# \text{Distance of the second train} = 90t
# \]
#
# Since the two trains are traveling in opposite directions, the total distance between them will be the sum of the distances traveled by both trains:
# \[
# \text{Total distance} = 60t + 90t = 150t
# \]
#
# We want to find the time \( t \) at which the distance between the two trains is equal to 300 miles:
# \[
# 150t = 300
# \]
#
# Now, solving for \( t \):
# \[
# t = \frac{300}{150} = 2
# \]
#
# Thus, the time at which the distance between the two trains will be 300 miles is \( \boxed{2} \) hours.

# %%
messages = [{"role": "user", "content": "Suggest one promising business area where Agentic AI could create real commercial value. Respond with just the business area and one short reason."}]

response = openai_python_client.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages,
)

business_idea = response.choices[0].message.content

print(business_idea)
# Out:
# Personalized Healthcare Management - Agentic AI can analyze patient data in real-time to offer tailored treatment plans and proactive health monitoring, improving patient outcomes and reducing costs.

# %%
messages = [{"role": "user", "content": f"In the business area '{business_idea}', describe one painful, expensive, or repetitive problem that could be solved with Agentic AI. Keep it concise."}]

response = openai_python_client.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages,
)

problem = response.choices[0].message.content

print(problem)
# Out:
# One painful issue in personalized healthcare management is the inefficiency in coordinating patient care. Patients often experience fragmented treatment across various healthcare providers, leading to duplicated tests, miscommunications, and inconsistent treatment plans. Agentic AI can streamline this process by aggregating real-time patient data from multiple sources, enabling seamless collaboration among healthcare teams. This reduces unnecessary costs, minimizes the risk of errors, and ensures patients receive cohesive and tailored treatment plans.

# %%
messages = [{"role": "user", "content": f"For the business area '{business_idea}' and this pain point: '{problem}', propose a specific Agentic AI solution. Explain what the agent would do, who would use it, and why it would be valuable."}]

response = openai_python_client.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages,
)

solution = response.choices[0].message.content

print(solution)
# Out:
# ### Agentic AI Solution: Patient Care Coordination Hub (PCCH)
#
# **Overview:**
# The Patient Care Coordination Hub (PCCH) is an AI-driven platform designed to streamline personalized healthcare management by aggregating real-time patient data from various sources, such as electronic health records (EHRs), lab results, wearable technology, and patient-reported outcomes. It fosters seamless collaboration among healthcare providers to create cohesive, personalized treatment plans while reducing redundancies and communication errors.
#
# **Functionality:**
# 1. **Real-Time Data Aggregation**: The PCCH continuously collects and synthesizes patient data from multiple healthcare providers, ensuring a comprehensive view of the patient's health status and treatment history.
#
# ...

# %%
from IPython.display import Markdown, display

display(Markdown(f"# {solution}"))
# Out:
# # ### Agentic AI Solution: Patient Care Coordination Hub (PCCH)
#
# **Overview:**
# The Patient Care Coordination Hub (PCCH) is an AI-driven platform designed to streamline personalized healthcare management by aggregating real-time patient data from various sources, such as electronic health records (EHRs), lab results, wearable technology, and patient-reported outcomes. It fosters seamless collaboration among healthcare providers to create cohesive, personalized treatment plans while reducing redundancies and communication errors.
#
# **Functionality:**
# 1. **Real-Time Data Aggregation**: The PCCH continuously collects and synthesizes patient data from multiple healthcare providers, ensuring a comprehensive view of the patient's health status and treatment history.
#
# ...
